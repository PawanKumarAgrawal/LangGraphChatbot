# %%
# %pip install langchain-openai langchain-community python-dotenv faiss-cpu pypdf
# Out:
# Requirement already satisfied: langchain-openai in .\myenv\Lib\site-packages (0.3.32)
# Requirement already satisfied: langchain-community in .\myenv\Lib\site-packages (0.3.31)
# Requirement already satisfied: python-dotenv in .\myenv\Lib\site-packages (1.1.1)
# Requirement already satisfied: faiss-cpu in .\myenv\Lib\site-packages (1.13.2)
# Requirement already satisfied: pypdf in .\myenv\Lib\site-packages (6.7.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.74 in .\myenv\Lib\site-packages (from langchain-openai) (0.3.83)
# Requirement already satisfied: openai<2.0.0,>=1.99.9 in .\myenv\Lib\site-packages (from langchain-openai) (1.102.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in .\myenv\Lib\site-packages (from langchain-openai) (0.11.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in .\myenv\Lib\site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (0.4.21)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in .\myenv\Lib\site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in .\myenv\Lib\site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in .\myenv\Lib\site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (6.0.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in .\myenv\Lib\site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in .\myenv\Lib\site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in .\myenv\Lib\site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (2.11.7)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in .\myenv\Lib\site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in .\myenv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.74->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in .\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in .\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in .\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in .\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (0.24.0)
# Requirement already satisfied: anyio in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (4.10.0)
# Requirement already satisfied: certifi in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (3.10)
# Requirement already satisfied: h11>=0.16 in .\myenv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in .\myenv\Lib\site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in .\myenv\Lib\site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in .\myenv\Lib\site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in .\myenv\Lib\site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in .\myenv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.74->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in .\myenv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.74->langchain-openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in .\myenv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.74->langchain-openai) (0.4.1)
# Requirement already satisfied: regex>=2022.1.18 in .\myenv\Lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2025.9.1)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in .\myenv\Lib\site-packages (from langchain-community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in .\myenv\Lib\site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in .\myenv\Lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in .\myenv\Lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in .\myenv\Lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in .\myenv\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in .\myenv\Lib\site-packages (from langchain-community) (2.3.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in .\myenv\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in .\myenv\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in .\myenv\Lib\site-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (0.3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\myenv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\myenv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (2.5.0)
# Requirement already satisfied: greenlet>=1 in .\myenv\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in .\myenv\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: colorama in .\myenv\Lib\site-packages (from tqdm>4->openai<2.0.0,>=1.99.9->langchain-openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from dotenv import load_dotenv
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_core.tools import tool

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
loader = PyPDFLoader("my_thesis.pdf")
docs = loader.load()

# %%
len(docs)
# Out:
# 145

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = splitter.split_documents(docs)

# %%
len(chunks)
# Out:
# 305

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

vector_store = FAISS.from_documents(chunks, embeddings)

# %%
vector_store

# %%
retriever = vector_store.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 3}
)

# %%
retriever.invoke("Who is the author of this thesis?")
# Out:
# [Document(id='982cfa19-e35a-4e32-a330-2b0296806dd5', metadata={'producer': 'Microsoft® Word 2016', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-02-23T13:14:07+05:30', 'author': 'Windows User', 'moddate': '2026-02-23T13:14:07+05:30', 'source': 'my_thesis.pdf', 'total_pages': 145, 'page': 1, 'page_label': '2'}, page_content='Acknowledgement  \n \nIt’s the solemn benediction of God who has given me the opportunity to \nprepare this manuscript. All my sincere gratitude goes to him for his blessings. \nI am filled with everlasting enthusiasm, pride, and pleasure as I express my \ndeep sense of gratitude to my Advisor and Chairman of the Advisory Committee Dr. \nVinay Kumar Singh, Professor, Department of Mechanical Engineering for his inspiring \nguidance, encouragement, and unwavering efforts throughout the course of this work. \nHis timely assistance, constructive criticism, and diligent efforts made it possible for \nme to present the work contained in this thesis. \nEspecially I extend my deep sense of indebtedness and gratitude to the \nmembers of the Advisory Committee Dr. Jitendra Bhaskar, Professor, Department of \nMechanical Engineering, HBTU, Kanpur, Dr. A. K. Chaudha ry, Associate Professor, \nDepartment of Industrial and Production Engineering and Dr. Sakshi Chauhan,'),
#  Document(id='ef2d1b5c-d0ba-41c8-841d-afd6f718fd43', metadata={'producer': 'Microsoft® Word 2016', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-02-23T13:14:07+05:30', 'author': 'Windows User', 'moddate': '2026-02-23T13:14:07+05:30', 'source': 'my_thesis.pdf', 'total_pages': 145, 'page': 2, 'page_label': '3'}, page_content='CERTIFICATE–I \n \nThis is to certify that the thesis entitled “Investigations on the Synergistic \nImpact of Fumaric Acid Cross -Linking and Modified Graphite Particle \nReinforcement on Polyvinyl Alcohol -Based Composite ” submitted in partial \nfulfilment of the requirements for the degree of Doctor of Philosophy  with major \nin Mechanical Engineering and  minor in Production Engineering of the College \nof Post Graduate Studies, G. B. Pant University of Agriculture and Technology, \nPantnagar, is a record of bona fide research carried out by Mr. Pawan Kumar \nAgrawal, Id. No. 21845 under my super vision and no part of the thesis has been \nsubmitted for any other degree or diploma. \nThe assistance and help received during the course of this investigation \nhave been duly acknowledged. \n \n \n \nPantnagar (V. K. Singh) \nMay, 2023 Chairman \n Advisory Committee'),
#  Document(id='4fb7b1b0-7e3f-44dd-a0b1-c2dc23bd7f0b', metadata={'producer': 'Microsoft® Word 2016', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-02-23T13:14:07+05:30', 'author': 'Windows User', 'moddate': '2026-02-23T13:14:07+05:30', 'source': 'my_thesis.pdf', 'total_pages': 145, 'page': 1, 'page_label': '2'}, page_content='Mechanical Engineering, HBTU, Kanpur, Dr. A. K. Chaudha ry, Associate Professor, \nDepartment of Industrial and Production Engineering and Dr. Sakshi Chauhan, \nAssistant Professor, Department of Department of Mechanical Engineering, for their \ncontribution, suggestion and valuable guidance during the course of investigation and  \nthesis writing. \nI am highly thankful to Dr. Lokesh Varshney, Professor and Head, Department \nof Mechanical Engineering for his kind support during the course of my research work. \nI would also like to thanks Ms. Pragya Sharma, Mr. Abhishek Chandra and Mr. \nShalinder Kumar Singh for their helping hand at various stage of research work. \nI deem it my privilege to express my heartiest and sincere thanks to Dr. Kiran \nP. Raverkar, Dean, College of Post Graduate Studies and Dr. Alaknanda Ashok, Dean, \nCollege of Technology, for their keen interest in providing me the necessary facilities.')]

# %%
@tool
def rag_tool(query: str):
    """
    Retrieve relevant information from the PDF document.
    Use this tool when the user asks factual / conceptual questions
    that might be answered from the stored documents.
    """
    
    result = retriever.invoke(query)

    context = [doc.page_content for doc in result]
    metadata = [doc.metadata for doc in result]

    return {
        "query": query,
        "context": context,
        "metadata": metadata
    }

# %%
query = "Who is the author of this thesis ?"

# %%
rag = rag_tool.invoke({"query": query})


prompt = f"""Answer the question using the context and metadata.

Question:
{rag['query']}

Context:
{"\n\n".join(rag["context"])}

Metadata:
{"\n".join([str(m) for m in rag["metadata"]])}

"""

answer = llm.invoke(prompt)

print("Answer:\n", answer.content)
# Out:
# Answer:
#  The author of the thesis is Mr. Pawan Kumar Agrawal.
